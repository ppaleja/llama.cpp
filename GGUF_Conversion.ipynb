# %% [markdown]
# # GGUF Conversion Verification for Motif Models
#
# This notebook verifies the GGUF conversion support for Motif architecture models in `llama.cpp`.

# %%
# Install dependencies
# !pip install -r requirements.txt
# !pip install huggingface_hub

# %%
# Convert Motif-2.6b-v1.1-LC model
# Note: ensuring we are using the local modified convert_hf_to_gguf.py
# !python3 convert_hf_to_gguf.py Motif-Technologies/Motif-2.6b-v1.1-LC --outtype f16 --verbose

# %%
# List generated GGUF files
# !ls -lh *.gguf
