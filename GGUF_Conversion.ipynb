# %% [markdown]
# <a href="https://colab.research.google.com/github/ppaleja/llama.cpp/blob/bugfix%2FmotifGGUFconverter/GGUF_Conversion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GGUF Conversion Verification for Motif Models
#
# This notebook verifies the GGUF conversion support for Motif architecture models in `llama.cpp`.

# %%
!%cd /content/
# !git clone https://github.com/ppaleja/llama.cpp.git
# %cd llama.cpp
# !git checkout feature/motifGGUFconverter
# Out:
# /bin/bash: line 1: fg: no job control
# Cloning into 'llama.cpp'...
# remote: Enumerating objects: 56338, done.
# remote: Counting objects: 100% (76/76), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 56338 (delta 53), reused 29 (delta 29), pack-reused 56262 (from 5)
# Receiving objects: 100% (56338/56338), 222.90 MiB | 51.73 MiB/s, done.
# Resolving deltas: 100% (40090/40090), done.
# /content/llama.cpp
# Branch 'feature/motifGGUFconverter' set up to track remote branch 'feature/motifGGUFconverter' from 'origin'.
# Switched to a new branch 'feature/motifGGUFconverter'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install dependencies
# %pip install -r requirements.txt
# %pip install huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/nightly, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/nightly, https://download.pytorch.org/whl/cpu, https://download.pytorch.org/whl/nightly
# Ignoring torch: markers 'platform_machine == "s390x"' don't match your environment
# Ignoring torch: markers 'platform_machine == "s390x"' don't match your environment
# Collecting numpy~=1.26.4 (from -r ./requirements/requirements-convert_legacy_llama.txt (line 1))
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: sentencepiece~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from -r ./requirements/requirements-convert_legacy_llama.txt (line 2)) (0.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.57.1 in /usr/local/lib/python3.12/dist-packages (from -r ./requirements/requirements-convert_legacy_llama.txt (line 4)) (4.57.3)
# Collecting gguf>=0.1.0 (from -r ./requirements/requirements-convert_legacy_llama.txt (line 6))
#   Downloading https://download.pytorch.org/whl/nightly/gguf-0.17.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting protobuf<5.0.0,>=4.21.0 (from -r ./requirements/requirements-convert_legacy_llama.txt (line 7))
#   Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Collecting torch~=2.6.0 (from -r ./requirements/requirements-convert_hf_to_gguf.txt (line 5))
#   Downloading https://download.pytorch.org/whl/cpu/torch-2.6.0%2Bcpu-cp312-cp312-linux_x86_64.whl.metadata (26 kB)
# Collecting aiohttp~=3.9.3 (from -r ./requirements/requirements-tool_bench.txt (line 1))
#   Downloading https://download.pytorch.org/whl/nightly/aiohttp-3.9.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.6 MB/s eta 0:00:00
# Collecting pytest~=8.3.3 (from -r ./requirements/requirements-tool_bench.txt (line 2))
#   Downloading pytest-8.3.5-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: huggingface_hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from -r ./requirements/requirements-tool_bench.txt (line 3)) (0.36.0)
# Requirement already satisfied: matplotlib~=3.10.0 in /usr/local/lib/python3.12/dist-packages (from -r ./requirements/requirements-tool_bench.txt (line 4)) (3.10.0)
# Collecting openai~=1.55.3 (from -r ./requirements/requirements-tool_bench.txt (line 6))
#   Downloading openai-1.55.3-py3-none-any.whl.metadata (24 kB)
# Collecting pandas~=2.2.3 (from -r ./requirements/requirements-tool_bench.txt (line 7))
#   Downloading https://download.pytorch.org/whl/nightly/pandas-2.2.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 108.2 MB/s eta 0:00:00
# Collecting prometheus-client~=0.20.0 (from -r ./requirements/requirements-tool_bench.txt (line 8))
#   Downloading prometheus_client-0.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: requests~=2.32.3 in /usr/local/lib/python3.12/dist-packages (from -r ./requirements/requirements-tool_bench.txt (line 9)) (2.32.4)
# Collecting wget~=3.2 (from -r ./requirements/requirements-tool_bench.txt (line 10))
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Collecting typer~=0.15.1 (from -r ./requirements/requirements-tool_bench.txt (line 11))
#   Downloading typer-0.15.4-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: seaborn~=0.13.2 in /usr/local/lib/python3.12/dist-packages (from -r ./requirements/requirements-tool_bench.txt (line 12)) (0.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.57.1->-r ./requirements/requirements-convert_legacy_llama.txt (line 4)) (3.20.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.57.1->-r ./requirements/requirements-convert_legacy_llama.txt (line 4)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.57.1->-r ./requirements/requirements-convert_legacy_llama.txt (line 4)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.57.1->-r ./requirements/requirements-convert_legacy_llama.txt (line 4)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.57.1->-r ./requirements/requirements-convert_legacy_llama.txt (line 4)) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.57.1->-r ./requirements/requirements-convert_legacy_llama.txt (line 4)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers<5.0.0,>=4.57.1->-r ./requirements/requirements-convert_legacy_llama.txt (line 4)) (4.67.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->-r ./requirements/requirements-convert_hf_to_gguf.txt (line 5)) (4.15.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->-r ./requirements/requirements-convert_hf_to_gguf.txt (line 5)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->-r ./requirements/requirements-convert_hf_to_gguf.txt (line 5)) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->-r ./requirements/requirements-convert_hf_to_gguf.txt (line 5)) (2025.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch~=2.6.0->-r ./requirements/requirements-convert_hf_to_gguf.txt (line 5)) (75.2.0)
# Collecting sympy==1.13.1 (from torch~=2.6.0->-r ./requirements/requirements-convert_hf_to_gguf.txt (line 5))
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy==1.13.1->torch~=2.6.0->-r ./requirements/requirements-convert_hf_to_gguf.txt (line 5)) (1.3.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.9.3->-r ./requirements/requirements-tool_bench.txt (line 1)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.9.3->-r ./requirements/requirements-tool_bench.txt (line 1)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.9.3->-r ./requirements/requirements-tool_bench.txt (line 1)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.9.3->-r ./requirements/requirements-tool_bench.txt (line 1)) (6.7.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp~=3.9.3->-r ./requirements/requirements-tool_bench.txt (line 1)) (1.22.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.12/dist-packages (from pytest~=8.3.3->-r ./requirements/requirements-tool_bench.txt (line 2)) (2.3.0)
# Requirement already satisfied: pluggy<2,>=1.5 in /usr/local/lib/python3.12/dist-packages (from pytest~=8.3.3->-r ./requirements/requirements-tool_bench.txt (line 2)) (1.6.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub<1.0,>=0.34.0->-r ./requirements/requirements-tool_bench.txt (line 3)) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0->-r ./requirements/requirements-tool_bench.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0->-r ./requirements/requirements-tool_bench.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0->-r ./requirements/requirements-tool_bench.txt (line 4)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0->-r ./requirements/requirements-tool_bench.txt (line 4)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0->-r ./requirements/requirements-tool_bench.txt (line 4)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0->-r ./requirements/requirements-tool_bench.txt (line 4)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib~=3.10.0->-r ./requirements/requirements-tool_bench.txt (line 4)) (2.9.0.post0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai~=1.55.3->-r ./requirements/requirements-tool_bench.txt (line 6)) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai~=1.55.3->-r ./requirements/requirements-tool_bench.txt (line 6)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai~=1.55.3->-r ./requirements/requirements-tool_bench.txt (line 6)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai~=1.55.3->-r ./requirements/requirements-tool_bench.txt (line 6)) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai~=1.55.3->-r ./requirements/requirements-tool_bench.txt (line 6)) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai~=1.55.3->-r ./requirements/requirements-tool_bench.txt (line 6)) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas~=2.2.3->-r ./requirements/requirements-tool_bench.txt (line 7)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas~=2.2.3->-r ./requirements/requirements-tool_bench.txt (line 7)) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32.3->-r ./requirements/requirements-tool_bench.txt (line 9)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32.3->-r ./requirements/requirements-tool_bench.txt (line 9)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32.3->-r ./requirements/requirements-tool_bench.txt (line 9)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests~=2.32.3->-r ./requirements/requirements-tool_bench.txt (line 9)) (2025.11.12)
# Collecting click<8.2,>=8.0.0 (from typer~=0.15.1->-r ./requirements/requirements-tool_bench.txt (line 11))
#   Downloading click-8.1.8-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer~=0.15.1->-r ./requirements/requirements-tool_bench.txt (line 11)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.12/dist-packages (from typer~=0.15.1->-r ./requirements/requirements-tool_bench.txt (line 11)) (13.9.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai~=1.55.3->-r ./requirements/requirements-tool_bench.txt (line 6)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai~=1.55.3->-r ./requirements/requirements-tool_bench.txt (line 6)) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai~=1.55.3->-r ./requirements/requirements-tool_bench.txt (line 6)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai~=1.55.3->-r ./requirements/requirements-tool_bench.txt (line 6)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai~=1.55.3->-r ./requirements/requirements-tool_bench.txt (line 6)) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib~=3.10.0->-r ./requirements/requirements-tool_bench.txt (line 4)) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer~=0.15.1->-r ./requirements/requirements-tool_bench.txt (line 11)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=10.11.0->typer~=0.15.1->-r ./requirements/requirements-tool_bench.txt (line 11)) (2.19.2)
# Requirement already satisfied: propcache>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from yarl<2.0,>=1.0->aiohttp~=3.9.3->-r ./requirements/requirements-tool_bench.txt (line 1)) (0.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch~=2.6.0->-r ./requirements/requirements-convert_hf_to_gguf.txt (line 5)) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer~=0.15.1->-r ./requirements/requirements-tool_bench.txt (line 11)) (0.1.2)
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 121.4 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/nightly/gguf-0.17.1-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.2/96.2 kB 7.2 MB/s eta 0:00:00
# Downloading protobuf-4.25.8-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 21.8 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/cpu/torch-2.6.0%2Bcpu-cp312-cp312-linux_x86_64.whl (178.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.6/178.6 MB 9.0 MB/s eta 0:00:00
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 126.5 MB/s eta 0:00:00
# Downloading pytest-8.3.5-py3-none-any.whl (343 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.6/343.6 kB 24.4 MB/s eta 0:00:00
# Downloading openai-1.55.3-py3-none-any.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.6/389.6 kB 21.1 MB/s eta 0:00:00
# Downloading prometheus_client-0.20.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.2 MB/s eta 0:00:00
# Downloading typer-0.15.4-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.3/45.3 kB 2.9 MB/s eta 0:00:00
# Downloading click-8.1.8-py3-none-any.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 6.5 MB/s eta 0:00:00
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=b1c6e041c979145a26103bad8bb9e603d3b7f7c45c2c173e867d80feb6f8ec71
#   Stored in directory: /root/.cache/pip/wheels/01/46/3b/e29ffbe4ebe614ff224bad40fc6a5773a67a163251585a13a9
# Successfully built wget
# Installing collected packages: wget, sympy, pytest, protobuf, prometheus-client, numpy, click, torch, pandas, gguf, aiohttp, typer, openai
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.14.0
#     Uninstalling sympy-1.14.0:
#       Successfully uninstalled sympy-1.14.0
#   Attempting uninstall: pytest
#     Found existing installation: pytest 8.4.2
#     Uninstalling pytest-8.4.2:
#       Successfully uninstalled pytest-8.4.2
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: prometheus-client
#     Found existing installation: prometheus_client 0.23.1
#     Uninstalling prometheus_client-0.23.1:
#       Successfully uninstalled prometheus_client-0.23.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
#   Attempting uninstall: torch
#     Found existing installation: torch 2.9.0+cpu
#     Uninstalling torch-2.9.0+cpu:
#       Successfully uninstalled torch-2.9.0+cpu
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.13.2
#     Uninstalling aiohttp-3.13.2:
#       Successfully uninstalled aiohttp-3.13.2
#   Attempting uninstall: typer
#     Found existing installation: typer 0.20.0
#     Uninstalling typer-0.20.0:
#       Successfully uninstalled typer-0.20.0
#   Attempting uninstall: openai
#     Found existing installation: openai 2.12.0
#     Uninstalling openai-2.12.0:
#       Successfully uninstalled openai-2.12.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# torchaudio 2.9.0+cpu requires torch==2.9.0, but you have torch 2.6.0+cpu which is incompatible.
# ydf 0.13.0 requires protobuf<7.0.0,>=5.29.1, but you have protobuf 4.25.8 which is incompatible.
# torchvision 0.24.0+cpu requires torch==2.9.0, but you have torch 2.6.0+cpu which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opentelemetry-proto 1.37.0 requires protobuf<7.0,>=5.0, but you have protobuf 4.25.8 which is incompatible.
# grpcio-status 1.71.2 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 4.25.8 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# Successfully installed aiohttp-3.9.5 click-8.1.8 gguf-0.17.1 numpy-1.26.4 openai-1.55.3 pandas-2.2.3 prometheus-client-0.20.0 protobuf-4.25.8 pytest-8.3.5 sympy-1.13.1 torch-2.6.0+cpu typer-0.15.4 wget-3.2
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2025.11.12)

# %%
# Download the model from Hugging Face to Local VM
from huggingface_hub import snapshot_download
import os

model_id = "Motif-Technologies/Motif-2-12.7B-Instruct"
# Use local VM path for better stability and speed
model_dir = f"/content/{model_id.split('/')[-1]}"

if os.path.exists(model_dir):
    print(f"Model found at {model_dir}. Skipping download.")
else:
    print(f"Downloading {model_id} to {model_dir}...")
    snapshot_download(repo_id=model_id, local_dir=model_dir, local_dir_use_symlinks=False)
    print("Download complete.")
# Out:
# Downloading Motif-Technologies/Motif-2-12.7B-Instruct to /content/Motif-2-12.7B-Instruct...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:979: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# Fetching 24 files:   0%|          | 0/24 [00:00<?, ?it/s]
# configuration_motif.py: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# added_tokens.json: 0.00B [00:00, ?B/s]
# generation_config.json:   0%|          | 0.00/143 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# model-00001-of-00011.safetensors:   0%|          | 0.00/4.97G [00:00<?, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# model-00002-of-00011.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00005-of-00011.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00006-of-00011.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00004-of-00011.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00007-of-00011.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00003-of-00011.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00008-of-00011.safetensors:   0%|          | 0.00/4.90G [00:00<?, ?B/s]
# model-00009-of-00011.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# model-00010-of-00011.safetensors:   0%|          | 0.00/2.99G [00:00<?, ?B/s]
# model-00011-of-00011.safetensors:   0%|          | 0.00/3.60G [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# modeling_motif.py: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/589 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.3M [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# Download complete.

# %%
with open('/content/llama.cpp/gguf-py/gguf/constants.py', 'r') as f:
    lines = f.readlines()

print("Searching for MODEL_TENSORS...")
for i, line in enumerate(lines):
    if 'MODEL_TENSORS' in line and '=' in line:
        print(f"Found definition at line {i+1}: {line.strip()}")
        # Print surrounding lines to see context
        print("".join(lines[i:i+20]))
        break

print("\nSearching for MODEL_ARCH definition...")
for i, line in enumerate(lines):
    if 'class MODEL_ARCH' in line:
        print(f"Found Enum at line {i+1}")
        # Print the end of the enum to see if MOTIF is there
        # Heuristic: look for lines indented until unindent
        j = i + 1
        while j < len(lines) and (lines[j].startswith('    ') or lines[j].strip() == ''):
            if 'MOTIF' in lines[j]:
                print(f"Found MOTIF at line {j+1}: {lines[j].strip()}")
            j += 1
        break
# Out:
# Searching for MODEL_TENSORS...
# Found definition at line 1107: MODEL_TENSORS: dict[MODEL_ARCH, list[MODEL_TENSOR]] = {
# MODEL_TENSORS: dict[MODEL_ARCH, list[MODEL_TENSOR]] = {
#     MODEL_ARCH.MMPROJ: [
#         MODEL_TENSOR.V_MMPROJ,
#         MODEL_TENSOR.V_MMPROJ_FC,
#         MODEL_TENSOR.V_MMPROJ_MLP,
#         MODEL_TENSOR.V_MMPROJ_PEG,
#         MODEL_TENSOR.V_ENC_EMBD_CLS,
#         MODEL_TENSOR.V_ENC_EMBD_PATCH,
#         MODEL_TENSOR.V_ENC_EMBD_POS,
#         MODEL_TENSOR.V_ENC_INPUT_NORM,
#         MODEL_TENSOR.V_ENC_ATTN_QKV,
#         MODEL_TENSOR.V_ENC_ATTN_Q,
#         MODEL_TENSOR.V_ENC_ATTN_Q_NORM,
#         MODEL_TENSOR.V_ENC_ATTN_K,
#         MODEL_TENSOR.V_ENC_ATTN_K_NORM,
#         MODEL_TENSOR.V_ENC_ATTN_V,
#         MODEL_TENSOR.V_ENC_ATTN_O,
#         MODEL_TENSOR.V_ENC_ATTN_O_NORM,
#         MODEL_TENSOR.V_ENC_POST_ATTN_NORM,
#         MODEL_TENSOR.V_ENC_FFN_UP,
#
#
# Searching for MODEL_ARCH definition...
# Found Enum at line 345
# Found MOTIF at line 453: MOTIF            = auto()

# %%
with open('/content/llama.cpp/gguf-py/gguf/tensor_mapping.py', 'r') as f:
    content = f.read()

# Show the beginning of MODEL_TENSORS definition to understand the structure
start_idx = content.find('MODEL_TENSORS = {')
print(content[start_idx:start_idx+500])

# Also check if MODEL_ARCH is imported
print("\nImports:")
print(content[:300])
# Out:
# Imports:
# from __future__ import annotations
#
# from typing import Sequence
#
# from .constants import MODEL_ARCH, MODEL_TENSOR, MODEL_TENSORS, TENSOR_NAMES
#
#
# class TensorNameMap:
#     mappings_cfg: dict[MODEL_TENSOR, tuple[str, ...]] = {
#         # Token embeddings
#         MODEL_TENSOR.TOKEN_EMBD: (
#             "gp

# %%
# Convert the model to GGUF
# Saving to local VM storage (/content/)
output_file = "/content/Motif-2-12.7B-Instruct-f16.gguf"

print(f"Converting model from {model_dir} to GGUF...")
print(f"Saving output to local VM disk: {output_file}")

# !python3 convert_hf_to_gguf.py "{model_dir}" --outtype f16 --outfile "{output_file}" --verbose
# Out:
# Converting model from /content/Motif-2-12.7B-Instruct to GGUF...
# Saving output to local VM disk: /content/Motif-2-12.7B-Instruct-f16.gguf
# INFO:hf-to-gguf:Loading model: Motif-2-12.7B-Instruct
# WARNING:hf-to-gguf:Failed to load model config from /content/Motif-2-12.7B-Instruct: The repository /content/Motif-2-12.7B-Instruct contains custom code which must be executed to correctly load the model. You can inspect the repository content at /content/Motif-2-12.7B-Instruct .
#  You can inspect the repository content at https://hf.co//content/Motif-2-12.7B-Instruct.
# Please pass the argument `trust_remote_code=True` to allow custom code to be run.
# WARNING:hf-to-gguf:Trying to load config.json instead
# INFO:hf-to-gguf:Model architecture: MotifForCausalLM
# WARNING:hf-to-gguf:Failed to load model config from /content/Motif-2-12.7B-Instruct: The repository /content/Motif-2-12.7B-Instruct contains custom code which must be executed to correctly load the model. You can inspect the repository content at /content/Motif-2-12.7B-Instruct .
#  You can inspect the repository content at https://hf.co//content/Motif-2-12.7B-Instruct.
# Please pass the argument `trust_remote_code=True` to allow custom code to be run.
# WARNING:hf-to-gguf:Trying to load config.json instead
# INFO:hf-to-gguf:gguf: loading model weight map from 'model.safetensors.index.json'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00001-of-00011.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00008-of-00011.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00009-of-00011.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00003-of-00011.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00010-of-00011.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00005-of-00011.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00007-of-00011.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00006-of-00011.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00002-of-00011.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00011-of-00011.safetensors'
# INFO:hf-to-gguf:gguf: indexing model part 'model-00004-of-00011.safetensors'
# INFO:gguf.gguf_writer:gguf: This GGUF file is for Little Endian only
# INFO:hf-to-gguf:Exporting model...
# INFO:hf-to-gguf:token_embd.weight,              torch.float32 --> F16, shape = {4096, 219520}
# INFO:hf-to-gguf:blk.0.attn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.0.ffn_polynorm_b,           torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.0.ffn_polynorm_w,           torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.0.ffn_down.weight,          torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.0.ffn_gate.weight,          torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.0.ffn_up.weight,            torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.0.ffn_norm.weight,          torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.0.attn_k.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.0.attn_lambda_k1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.0.attn_lambda_k2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.0.attn_lambda_q1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.0.attn_lambda_q2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.0.attn_output.weight,       torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.0.attn_q.weight,            torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.0.attn_sub_norm.weight,     torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.0.attn_v.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.1.attn_k.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.1.attn_lambda_k1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.1.attn_lambda_k2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.1.attn_lambda_q1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.1.attn_lambda_q2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.1.attn_output.weight,       torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.1.attn_q.weight,            torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.1.attn_sub_norm.weight,     torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.1.attn_v.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.28.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.28.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.28.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.28.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.28.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.28.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.28.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.29.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.29.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.29.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.29.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.29.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.29.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.29.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.29.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.29.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.29.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.29.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.29.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.29.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.29.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.29.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.29.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.30.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.30.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.30.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.30.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.30.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.30.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.30.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.30.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.30.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.30.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.30.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.30.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.30.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.30.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.30.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.30.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.31.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.31.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.31.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.31.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.31.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.31.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.31.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.31.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.31.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.31.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.31.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.31.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.31.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.31.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.31.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.31.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.32.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.32.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.32.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.32.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.32.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.32.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.32.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.32.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.32.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.32.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.32.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.32.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.32.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.32.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.32.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.32.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.33.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.33.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.33.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.33.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.33.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.33.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.33.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.33.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.33.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.33.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.33.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.33.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.33.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.33.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.33.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.33.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.34.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.34.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.34.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.34.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.34.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.34.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.34.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.34.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.34.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.34.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.34.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.34.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.34.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.34.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.34.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.34.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.35.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.35.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.35.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.35.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.35.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.35.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.35.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.35.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.35.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.35.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.35.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.35.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.35.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.35.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.35.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.35.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.36.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.36.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.36.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.36.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.36.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.36.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.36.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.36.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.36.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.36.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.36.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.36.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.36.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.36.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.36.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.36.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.37.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.37.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.37.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.37.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.37.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.37.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.37.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.37.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.37.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.10.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.10.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.10.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.10.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.10.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.10.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.10.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.10.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.10.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.5.attn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.5.ffn_polynorm_b,           torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.5.ffn_polynorm_w,           torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.5.ffn_down.weight,          torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.5.ffn_norm.weight,          torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.6.attn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.6.ffn_polynorm_b,           torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.6.ffn_polynorm_w,           torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.6.ffn_down.weight,          torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.6.ffn_gate.weight,          torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.6.ffn_up.weight,            torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.6.ffn_norm.weight,          torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.6.attn_k.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.6.attn_lambda_k1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.6.attn_lambda_k2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.6.attn_lambda_q1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.6.attn_lambda_q2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.6.attn_output.weight,       torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.6.attn_q.weight,            torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.6.attn_sub_norm.weight,     torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.6.attn_v.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.7.attn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.7.ffn_polynorm_b,           torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.7.ffn_polynorm_w,           torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.7.ffn_down.weight,          torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.7.ffn_gate.weight,          torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.7.ffn_up.weight,            torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.7.ffn_norm.weight,          torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.7.attn_k.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.7.attn_lambda_k1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.7.attn_lambda_k2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.7.attn_lambda_q1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.7.attn_lambda_q2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.7.attn_output.weight,       torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.7.attn_q.weight,            torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.7.attn_sub_norm.weight,     torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.7.attn_v.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.8.attn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.8.ffn_polynorm_b,           torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.8.ffn_polynorm_w,           torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.8.ffn_down.weight,          torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.8.ffn_gate.weight,          torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.8.ffn_up.weight,            torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.8.ffn_norm.weight,          torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.8.attn_k.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.8.attn_lambda_k1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.8.attn_lambda_k2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.8.attn_lambda_q1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.8.attn_lambda_q2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.8.attn_output.weight,       torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.8.attn_q.weight,            torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.8.attn_sub_norm.weight,     torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.8.attn_v.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.9.attn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.9.ffn_polynorm_b,           torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.9.ffn_polynorm_w,           torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.9.ffn_down.weight,          torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.9.ffn_gate.weight,          torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.9.ffn_up.weight,            torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.9.ffn_norm.weight,          torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.9.attn_k.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.9.attn_lambda_k1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.9.attn_lambda_k2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.9.attn_lambda_q1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.9.attn_lambda_q2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.9.attn_output.weight,       torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.9.attn_q.weight,            torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.9.attn_sub_norm.weight,     torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.9.attn_v.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.37.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.37.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.37.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.37.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.37.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.37.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.37.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.38.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.38.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.38.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.38.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.38.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.38.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.38.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.38.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.38.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.38.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.38.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.38.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.38.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.38.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.38.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.38.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.39.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.39.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.39.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.39.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.39.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.39.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.39.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.39.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.39.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.39.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.39.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.39.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.39.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.39.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.39.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.39.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:output_norm.weight,             torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.14.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.14.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.14.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.14.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.14.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.15.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.15.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.15.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.15.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.15.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.15.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.15.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.15.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.15.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.15.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.15.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.15.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.15.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.15.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.15.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.15.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.16.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.16.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.16.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.16.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.16.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.16.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.16.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.16.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.16.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.16.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.16.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.16.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.16.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.16.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.16.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.16.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.17.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.17.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.17.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.17.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.17.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.17.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.17.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.17.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.17.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.17.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.17.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.17.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.17.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.17.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.17.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.17.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.18.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.18.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.18.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.18.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.18.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.18.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.18.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.18.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.18.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.18.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.18.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.18.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.18.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.18.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.18.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.18.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.19.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.19.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.19.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.19.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.19.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.19.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.19.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.19.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.19.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.23.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.23.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.23.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.23.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.23.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.24.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.24.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.24.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.24.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.24.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.24.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.24.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.24.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.24.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.24.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.24.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.24.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.24.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.24.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.24.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.24.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.25.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.25.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.25.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.25.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.25.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.25.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.25.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.25.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.25.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.25.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.25.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.25.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.25.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.25.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.25.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.25.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.26.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.26.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.26.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.26.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.26.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.26.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.26.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.26.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.26.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.26.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.26.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.26.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.26.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.26.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.26.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.26.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.27.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.27.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.27.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.27.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.27.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.27.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.27.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.27.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.27.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.27.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.27.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.27.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.27.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.27.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.27.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.27.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.28.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.28.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.28.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.28.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.28.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.28.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.28.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.28.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.28.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.19.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.19.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.19.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.19.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.19.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.19.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.19.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.20.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.20.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.20.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.20.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.20.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.20.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.20.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.20.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.20.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.20.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.20.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.20.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.20.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.20.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.20.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.20.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.21.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.21.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.21.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.21.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.21.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.21.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.21.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.21.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.21.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.21.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.21.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.21.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.21.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.21.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.21.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.21.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.22.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.22.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.22.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.22.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.22.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.22.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.22.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.22.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.22.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.22.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.22.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.22.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.22.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.22.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.22.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.22.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.23.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.23.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.23.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.23.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.23.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.23.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.23.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.23.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.23.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.23.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.23.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.1.attn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.1.ffn_polynorm_b,           torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.1.ffn_polynorm_w,           torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.1.ffn_down.weight,          torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.1.ffn_gate.weight,          torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.1.ffn_up.weight,            torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.1.ffn_norm.weight,          torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.2.attn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.2.ffn_polynorm_b,           torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.2.ffn_polynorm_w,           torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.2.ffn_down.weight,          torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.2.ffn_gate.weight,          torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.2.ffn_up.weight,            torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.2.ffn_norm.weight,          torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.2.attn_k.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.2.attn_lambda_k1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.2.attn_lambda_k2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.2.attn_lambda_q1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.2.attn_lambda_q2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.2.attn_output.weight,       torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.2.attn_q.weight,            torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.2.attn_sub_norm.weight,     torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.2.attn_v.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.3.attn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.3.ffn_polynorm_b,           torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.3.ffn_polynorm_w,           torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.3.ffn_down.weight,          torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.3.ffn_gate.weight,          torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.3.ffn_up.weight,            torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.3.ffn_norm.weight,          torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.3.attn_k.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.3.attn_lambda_k1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.3.attn_lambda_k2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.3.attn_lambda_q1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.3.attn_lambda_q2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.3.attn_output.weight,       torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.3.attn_q.weight,            torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.3.attn_sub_norm.weight,     torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.3.attn_v.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.4.attn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.4.ffn_polynorm_b,           torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.4.ffn_polynorm_w,           torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.4.ffn_down.weight,          torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.4.ffn_gate.weight,          torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.4.ffn_up.weight,            torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.4.ffn_norm.weight,          torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.4.attn_k.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.4.attn_lambda_k1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.4.attn_lambda_k2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.4.attn_lambda_q1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.4.attn_lambda_q2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.4.attn_output.weight,       torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.4.attn_q.weight,            torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.4.attn_sub_norm.weight,     torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.4.attn_v.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.5.ffn_gate.weight,          torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.5.ffn_up.weight,            torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.5.attn_k.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.5.attn_lambda_k1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.5.attn_lambda_k2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.5.attn_lambda_q1,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.5.attn_lambda_q2,           torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.5.attn_output.weight,       torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.5.attn_q.weight,            torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.5.attn_sub_norm.weight,     torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.5.attn_v.weight,            torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:output.weight,                  torch.float32 --> F16, shape = {4096, 219520}
# INFO:hf-to-gguf:blk.10.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.10.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.10.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.10.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.10.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.10.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.10.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.11.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.11.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.11.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.11.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.11.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.11.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.11.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.11.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.11.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.11.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.11.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.11.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.11.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.11.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.11.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.11.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.12.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.12.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.12.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.12.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.12.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.12.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.12.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.12.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.12.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.12.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.12.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.12.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.12.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.12.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.12.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.12.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.13.attn_norm.weight,        torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.13.ffn_polynorm_b,          torch.float32 --> F32, shape = {1}
# INFO:hf-to-gguf:blk.13.ffn_polynorm_w,          torch.float32 --> F32, shape = {3}
# INFO:hf-to-gguf:blk.13.ffn_down.weight,         torch.float32 --> F16, shape = {16384, 4096}
# INFO:hf-to-gguf:blk.13.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.13.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.13.ffn_norm.weight,         torch.float32 --> F32, shape = {4096}
# INFO:hf-to-gguf:blk.13.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.13.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.13.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.13.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.13.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.13.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.13.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.13.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.13.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.14.ffn_gate.weight,         torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.14.ffn_up.weight,           torch.float32 --> F16, shape = {4096, 16384}
# INFO:hf-to-gguf:blk.14.attn_k.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:blk.14.attn_lambda_k1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.14.attn_lambda_k2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.14.attn_lambda_q1,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.14.attn_lambda_q2,          torch.float32 --> F32, shape = {128}
# INFO:hf-to-gguf:blk.14.attn_output.weight,      torch.float32 --> F16, shape = {8192, 4096}
# INFO:hf-to-gguf:blk.14.attn_q.weight,           torch.float32 --> F16, shape = {4096, 5120}
# INFO:hf-to-gguf:blk.14.attn_sub_norm.weight,    torch.float32 --> F32, shape = {256}
# INFO:hf-to-gguf:blk.14.attn_v.weight,           torch.float32 --> F16, shape = {4096, 2048}
# INFO:hf-to-gguf:Set meta model
# INFO:hf-to-gguf:Set model parameters
# INFO:hf-to-gguf:Set model quantization version
# INFO:hf-to-gguf:Set model tokenizer
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# DEBUG:hf-to-gguf:chktok: [126470, 25980, 160432, 16609, 2775, 4066, 172261, 19432, 112927, 222, 350, 14559, 8, 22861, 114, 2524, 64364, 104, 15148, 350, 76466, 166700, 121942, 780, 8, 91349, 9552, 99, 247, 4103, 99, 247, 220, 18, 220, 2546, 220, 15517, 220, 15517, 18, 220, 15517, 2546, 220, 15517, 15517, 220, 15517, 15517, 18, 220, 15517, 15517, 2546, 220, 18, 13, 18, 220, 18, 485, 18, 220, 18, 1008, 18, 44735, 107516, 15867, 20804, 22851, 134178, 77431, 32010, 104312, 156437, 1423, 7522, 18165, 2178, 34058, 22369, 16412, 32999, 16, 867, 8208, 105024, 106657, 1967, 53641, 1235, 185386, 8118, 22434, 39336, 26178, 26178, 168394, 194663, 27271, 147475, 25883, 6961, 9790, 1339, 461, 83, 1280, 19016, 1354, 11, 461, 1099, 481, 3239, 30, 461, 44, 625, 3239, 17291, 1520, 480, 11, 461, 35, 481, 1299, 1236, 17966, 30, 1416, 6, 27493, 261, 54602, 43]
# DEBUG:hf-to-gguf:chkhsh: ccc2ef013c104be7bae2965776d611e1d7a8a2a9c547dd93a682c9a9fc80352e
# DEBUG:hf-to-gguf:tokenizer.ggml.pre: 'gpt-4o'
# DEBUG:hf-to-gguf:chkhsh: ccc2ef013c104be7bae2965776d611e1d7a8a2a9c547dd93a682c9a9fc80352e
# INFO:gguf.vocab:Adding 220116 merge(s).
# INFO:gguf.vocab:Setting special token type bos to 219396
# INFO:gguf.vocab:Setting special token type eos to 219395
# INFO:gguf.vocab:Setting special token type unk to 219395
# INFO:gguf.vocab:Setting special token type pad to 219395
# INFO:gguf.vocab:Setting chat_template to <|beginoftext|>{%- for message in messages -%}
# <|startofturn|>{%- if message.role == "system" -%}
# <|system|>
# {{ message.content }}
# {% if tools is defined and tools %}
# # Tools
#
# You may call one or more functions to assist with the user query.
# You are provided with function signatures within <tools></tools> XML tags:
# <tools>
# {%- for tool in tools %}
# {{ tool | tojson }}
# {%- if not loop.last %}
# {%- endif %}
# {%- endfor %}
# </tools>
# Use this exact JSON schema for each tool call:
# {"properties":{"name":{"title":"Name","type":"string"},"arguments":{"title":"Arguments","type":"object"}},"required":["name","arguments"],"title":"FunctionCall","type":"object"}
#
# For each function call return a json object with function name and arguments within <tool_call></tool_call> XML tags as follows:
# <tool_call>
# {"name": <function-name>, "arguments": <args-dict>}
# </tool_call>
# {% endif %}
# {{- '<|endofturn|>' }}{%- elif message.role == "user" -%}
# <|user|>
# {{ message.content }}
# <|endofturn|>{%- elif message.role == "assistant" -%}
# <|assistant|>
# {%- set raw_calls = (message.tool_calls if (message.tool_calls is defined and message.tool_calls) else message.tool_call) %}
# {%- if raw_calls %}
# {%- set tool_calls = (raw_calls if (raw_calls is iterable and (raw_calls is not mapping) and (raw_calls is not string)) else [raw_calls]) %}
# {%- for tc in tool_calls %}
# {%- set call = (tc.function if tc.function is defined else tc) %}
# <tool_call>
# {"name": "{{ call.name }}", "arguments": {{ call.arguments if call.arguments is string else (call.arguments|default({})|tojson) }}}
# </tool_call>
# {%- endfor %}
# {%- endif %}
# {%- if message.thinking is defined and message.thinking %}
# {{ '<think>' }}
# {{ message.thinking }}
# {{ '</think>' }}
# {% endif %}
# {{ message.content }}
# <|endofturn|>{%- elif message.role == "tool" -%}
# <|tool|>
# <tool_response>
# {{ message.content }}
# </tool_response><|endofturn|>
# {%- endif -%}
# {%- endfor -%}
# {%- if add_generation_prompt and enable_thinking %}
# {{- '<|assistant|><think>\n' }}
# {%- elif add_generation_prompt %}
# {{- '<|assistant|>\n' }}
# {%- else %}
# <|endoftext|>
# {%- endif %}
# INFO:gguf.gguf_writer:Writing the following files:
# INFO:gguf.gguf_writer:/content/Motif-2-12.7B-Instruct-f16.gguf: n_tensors = 643, total_size = 25.4G
# Writing: 100% 25.4G/25.4G [04:06<00:00, 103Mbyte/s]
# INFO:hf-to-gguf:Model successfully exported to /content/Motif-2-12.7B-Instruct-f16.gguf

# %%
# Check available disk space on Google Drive and Local VM
# !echo "--- Google Drive Space ---"
# !df -h /content/drive
# !echo -e "\n--- Local VM Space ---"
# !df -h /content
# Out:
# --- Google Drive Space ---
# Filesystem      Size  Used Avail Use% Mounted on
# drive           226G  101G  126G  45% /content/drive
#
# --- Local VM Space ---
# Filesystem      Size  Used Avail Use% Mounted on
# overlay         226G   94G  133G  42% /

# %%
# Check file sizes of the downloaded model on Drive
# !ls -lh "/content/drive/MyDrive/models/Motif-Technologies/Motif-2-12.7B-Instruct"
# Out:
# total 43G
# -rw------- 1 root root 3.6K Dec 17 00:48 added_tokens.json
# -rw------- 1 root root 2.1K Dec 17 00:48 chat_template.jinja
# -rw------- 1 root root 1.1K Dec 17 00:48 config.json
# -rw------- 1 root root 9.2K Dec 17 00:48 configuration_motif.py
# -rw------- 1 root root  143 Dec 17 00:48 generation_config.json
# -rw------- 1 root root 4.7G Dec 17 00:50 model-00001-of-00011.safetensors
# -rw------- 1 root root 4.6G Dec 17 00:50 model-00002-of-00011.safetensors
# -rw------- 1 root root 4.6G Dec 17 00:50 model-00003-of-00011.safetensors
# -rw------- 1 root root 4.6G Dec 17 00:50 model-00004-of-00011.safetensors
# -rw------- 1 root root 4.6G Dec 17 00:51 model-00005-of-00011.safetensors
# -rw------- 1 root root 4.6G Dec 17 00:50 model-00006-of-00011.safetensors
# -rw------- 1 root root    0 Dec 17 00:51 model-00007-of-00011.safetensors
# -rw------- 1 root root 4.6G Dec 17 00:50 model-00008-of-00011.safetensors
# -rw------- 1 root root 4.6G Dec 17 00:51 model-00009-of-00011.safetensors
# -rw------- 1 root root 2.8G Dec 17 00:51 model-00010-of-00011.safetensors
# -rw------- 1 root root 3.4G Dec 17 00:51 model-00011-of-00011.safetensors
# -rw------- 1 root root  68K Dec 17 00:51 modeling_motif.py
# -rw------- 1 root root  51K Dec 17 00:51 model.safetensors.index.json
# -rw------- 1 root root 5.5K Dec 17 00:48 README.md
# -rw------- 1 root root  589 Dec 17 00:51 special_tokens_map.json
# -rw------- 1 root root  23K Dec 17 00:51 tokenizer_config.json
# -rw------- 1 root root  17M Dec 17 00:51 tokenizer.json
# -rw------- 1 root root 4.2M Dec 17 00:51 vocab.json

# %%
# List generated GGUF files in the local directory
# !ls -lh /content/*.gguf
# Out:
# -rw-r--r-- 1 root root 24G Dec 26 21:16 /content/Motif-2-12.7B-Instruct-f16.gguf

# %%
gguf_path = "/content/Motif-2-12.7B-Instruct-f16.gguf"

# %%
import gguf
import sys
import numpy as np
print(f"Verifying {gguf_path}...")
try:
    reader = gguf.GGUFReader(gguf_path)
except Exception as e:
    print(f"Error reading GGUF file: {e}")
# Out:
# Verifying /content/Motif-2-12.7B-Instruct-f16.gguf...

# %%
print("\n--- Key-Value Pairs (Motif/Attention specific) ---")
# assert architecture is motif
arch_key = next((k for k in reader.fields.keys() if "general.architecture" in k), None)
if arch_key:
    arch = str(reader.fields[arch_key].parts[-1], encoding='utf-8')
    print(f"Architecture: {arch}")
    assert arch == "motif", f"Expected architecture 'motif', got '{arch}'"
else:
    print("WARNING: Could not find general.architecture key")
# Out:
# --- Key-Value Pairs (Motif/Attention specific) ---
# Architecture: motif

# %%
relevant_keys = ["grouped_ratio", "k_ratio", "lambda_init", "num_noise_heads"]
found_keys = {}
for key, field in reader.fields.items():
    if any(k in key for k in relevant_keys):
          val = field.parts[-1]
          if isinstance(val, list): val = val[0] # Unpack single-item lists
          found_keys[key.split('.')[-1]] = val
          print(f"  {key}: {val}")
# Out:
#   {arch}.attention.num_noise_heads: [8]
#   {arch}.attention.grouped_ratio: [4.]
#   {arch}.attention.k_ratio: [1.]
#   {arch}.attention.lambda_init: [1.]

# %%
# Assertions for keys
if "grouped_ratio" in found_keys:
    # We expect 4.0 for Motif-2-12.7B
    assert found_keys["grouped_ratio"] == 4.0, f"Expected grouped_ratio=4.0, got {found_keys['grouped_ratio']}"

# %%
print("\n--- Tensors Check ---")
tensors = reader.tensors
print(f"  Total tensors found: {len(tensors)}")
# Out:
# --- Tensors Check ---
#   Total tensors found: 643

# %%
    # Map from our concept of the tensor to the GGUF name fragment we expect
    motif_specific_tensors = {
        "lambda_q1": "attn_lambda_q1",
        "lambda_k1": "attn_lambda_k1",
        "lambda_q2": "attn_lambda_q2",
        "lambda_k2": "attn_lambda_k2",
        "subln": "attn_sub_norm"
    }

    found_tensors = {k: 0 for k in motif_specific_tensors}

    for t in tensors:
        for user_name, gguf_name in motif_specific_tensors.items():
            if gguf_name in t.name:
                found_tensors[user_name] += 1

    all_found = True
    for name, count in found_tensors.items():
        if count == 0:
            print(f"  [FAILURE] Essential tensor '{name}' (mapped as *{motif_specific_tensors[name]}*) NOT found!")
            all_found = False
        else:
            print(f"  [OK] Found {count} instances of '{name}' (mapped as *{motif_specific_tensors[name]}*)")

    assert all_found, "Missing required Motif tensors!"
    print("\nSUCCESS: All Motif-specific tensor types appear to be present and values are within expected ranges.")
# Out:
#   [OK] Found 40 instances of 'lambda_q1' (mapped as *attn_lambda_q1*)
#   [OK] Found 40 instances of 'lambda_k1' (mapped as *attn_lambda_k1*)
#   [OK] Found 40 instances of 'lambda_q2' (mapped as *attn_lambda_q2*)
#   [OK] Found 40 instances of 'lambda_k2' (mapped as *attn_lambda_k2*)
#   [OK] Found 40 instances of 'subln' (mapped as *attn_sub_norm*)
#
# SUCCESS: All Motif-specific tensor types appear to be present and values are within expected ranges.
